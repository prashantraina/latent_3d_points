# %% [markdown]
# ## This notebook will help you train a vanilla Point-Cloud AE with the basic architecture we used in our paper.
#     (it assumes latent_3d_points is in the PYTHONPATH and the structural losses have been compiled)

# %%
import os.path as osp

from latent_3d_points.src.ae_templates import mlp_architecture_ala_iclr_18, default_train_params
from latent_3d_points.src.autoencoder import Configuration as Conf
from latent_3d_points.src.point_net_ae import PointNetAutoEncoder

from latent_3d_points.src.in_out import snc_category_to_synth_id, create_dir, PointCloudDataSet, \
                                        load_all_point_clouds_under_folder

from latent_3d_points.src.tf_utils import reset_tf_graph
# Out:
# /home/prashant/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Define Basic Parameters

# %%
top_out_dir = '../data/'                        # Use to write Neural-Net check-points etc.
top_in_dir = '../data/shape_net_core_uniform_samples_2048/' # Top-dir of where point-clouds are stored.

experiment_name = 'single_class_ae'
n_pc_points = 2048                              # Number of points per model.
bneck_size = 128                                # Bottleneck-AE size
ae_loss = 'emd'                             # Loss to optimize: 'emd' or 'chamfer'
class_name = input('Give me the class name (e.g. "chair"): ').lower()
# Out:
# Give me the class name (e.g. "chair"): piano

# %% [markdown]
# Load Point-Clouds

# %%
syn_id = snc_category_to_synth_id()[class_name]
class_dir = osp.join(top_in_dir , syn_id)
all_pc_data = load_all_point_clouds_under_folder(class_dir, n_threads=8, file_ending='.ply', verbose=True)
# Out:
# 239 pclouds were loaded. They belong in 1 shape-classes.

# %% [markdown]
# Load default training parameters (some of which are listed here). For more details please use print, etc.
#
#     'batch_size': 50
#
#     'denoising': False     (# by default AE is not denoising)
#
#     'learning_rate': 0.0005
#
#     'z_rotate': False      (# randomly rotate models of each batch)
#
#     'loss_display_step': 1 (# display loss at end of this many epochs)
#     'saver_step': 10       (# how many epochs to save neural-network)

# %%
train_dir = create_dir(osp.join(top_out_dir, experiment_name))
train_params = default_train_params()
encoder, decoder, enc_args, dec_args = mlp_architecture_ala_iclr_18(n_pc_points, bneck_size)

# %%
conf = Conf(n_input = [n_pc_points, 3],
            loss = ae_loss,
            training_epochs = train_params['training_epochs'],
            batch_size = train_params['batch_size'],
            denoising = train_params['denoising'],
            learning_rate = train_params['learning_rate'],
            train_dir = train_dir,
            loss_display_step = train_params['loss_display_step'],
            saver_step = train_params['saver_step'],
            z_rotate = train_params['z_rotate'],
            encoder = encoder,
            decoder = decoder,
            encoder_args = enc_args,
            decoder_args = dec_args
           )
conf.experiment_name = experiment_name
conf.held_out_step = 5              # How often to evaluate/print out loss on held_out data (if any).
conf.save(osp.join(train_dir, 'configuration'))

# %% [markdown]
# Build AE Model.

# %%
reset_tf_graph()
ae = PointNetAutoEncoder(conf.experiment_name, conf)
# Out:
# Building Encoder
# WARNING:tensorflow:From /home/prashant/miniconda3/lib/python3.6/site-packages/tflearn/initializations.py:119: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# ('encoder_conv_layer_0', 'conv params = ', 256)
# ('bnorm params = ', 128)
# Tensor("single_class_ae_2/Relu:0", shape=(?, 2048, 64), dtype=float32)
# ('output size:', 131072, '\n')
# ('encoder_conv_layer_1', 'conv params = ', 8320)
# ('bnorm params = ', 256)
# Tensor("single_class_ae_2/Relu_1:0", shape=(?, 2048, 128), dtype=float32)
# ('output size:', 262144, '\n')
# ('encoder_conv_layer_2', 'conv params = ', 16512)
# ('bnorm params = ', 256)
# Tensor("single_class_ae_2/Relu_2:0", shape=(?, 2048, 128), dtype=float32)
# ('output size:', 262144, '\n')
# ('encoder_conv_layer_3', 'conv params = ', 33024)
# ('bnorm params = ', 512)
# Tensor("single_class_ae_2/Relu_3:0", shape=(?, 2048, 256), dtype=float32)
# ('output size:', 524288, '\n')
# ('encoder_conv_layer_4', 'conv params = ', 32896)
# ('bnorm params = ', 256)
# Tensor("single_class_ae_2/Relu_4:0", shape=(?, 2048, 128), dtype=float32)
# ('output size:', 262144, '\n')
# Tensor("single_class_ae_2/Max:0", shape=(?, 128), dtype=float32)
# Building Decoder
# ('decoder_fc_0', 'FC params = ', 33024) Tensor("single_class_ae_2/Relu_5:0", shape=(?, 256), dtype=float32)
# ('output size:', 256, '\n')
# ('decoder_fc_1', 'FC params = ', 65792) Tensor("single_class_ae_2/Relu_6:0", shape=(?, 256), dtype=float32)
# ('output size:', 256, '\n')
# ('decoder_fc_2', 'FC params = ', 1579008) Tensor("single_class_ae_2/decoder_fc_2/BiasAdd:0", shape=(?, 6144), dtype=float32)
# ('output size:', 6144, '\n')

# %% [markdown]
# Train the AE (save output to train_stats.txt)

# %%
all_pc_data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0581ecc16f00> in <module>()
# ----> 1 all_pc_data.shape
#
# NameError: name 'all_pc_data' is not defined

# %%
buf_size = 1 # flush each line
fout = open(osp.join(conf.train_dir, 'train_stats.txt'), 'a', buf_size)
train_stats = ae.train(all_pc_data, conf, log_file=fout)
fout.close()
# Out:
# ('Epoch:', '0001', 'training time (minutes)=', '0.0259', 'loss=', '0.209051233')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-1 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0002', 'training time (minutes)=', '0.0142', 'loss=', '0.155892000')
# ('Epoch:', '0003', 'training time (minutes)=', '0.0141', 'loss=', '0.128058035')
# ('Epoch:', '0004', 'training time (minutes)=', '0.0143', 'loss=', '0.111596821')
# ('Epoch:', '0005', 'training time (minutes)=', '0.0141', 'loss=', '0.097377308')
# ('Epoch:', '0006', 'training time (minutes)=', '0.0141', 'loss=', '0.091807738')
# ('Epoch:', '0007', 'training time (minutes)=', '0.0141', 'loss=', '0.084795574')
# ('Epoch:', '0008', 'training time (minutes)=', '0.0141', 'loss=', '0.079756895')
# ('Epoch:', '0009', 'training time (minutes)=', '0.0142', 'loss=', '0.077223584')
# ('Epoch:', '0010', 'training time (minutes)=', '0.0143', 'loss=', '0.076235916')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-10 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0011', 'training time (minutes)=', '0.0143', 'loss=', '0.074494865')
# ('Epoch:', '0012', 'training time (minutes)=', '0.0147', 'loss=', '0.075035514')
# ('Epoch:', '0013', 'training time (minutes)=', '0.0142', 'loss=', '0.072225234')
# ('Epoch:', '0014', 'training time (minutes)=', '0.0144', 'loss=', '0.073313251')
# ('Epoch:', '0015', 'training time (minutes)=', '0.0141', 'loss=', '0.069016555')
# ('Epoch:', '0016', 'training time (minutes)=', '0.0141', 'loss=', '0.068975974')
# ('Epoch:', '0017', 'training time (minutes)=', '0.0141', 'loss=', '0.066396378')
# ('Epoch:', '0018', 'training time (minutes)=', '0.0141', 'loss=', '0.066342779')
# ('Epoch:', '0019', 'training time (minutes)=', '0.0141', 'loss=', '0.065918733')
# ('Epoch:', '0020', 'training time (minutes)=', '0.0141', 'loss=', '0.067567859')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-20 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0021', 'training time (minutes)=', '0.0140', 'loss=', '0.065323476')
# ('Epoch:', '0022', 'training time (minutes)=', '0.0143', 'loss=', '0.064347891')
# ('Epoch:', '0023', 'training time (minutes)=', '0.0143', 'loss=', '0.066080129')
# ('Epoch:', '0024', 'training time (minutes)=', '0.0141', 'loss=', '0.060527911')
# ('Epoch:', '0025', 'training time (minutes)=', '0.0140', 'loss=', '0.063822841')
# ('Epoch:', '0026', 'training time (minutes)=', '0.0141', 'loss=', '0.061009086')
# ('Epoch:', '0027', 'training time (minutes)=', '0.0141', 'loss=', '0.063033566')
# ('Epoch:', '0028', 'training time (minutes)=', '0.0141', 'loss=', '0.060002046')
# ('Epoch:', '0029', 'training time (minutes)=', '0.0141', 'loss=', '0.059521475')
# ('Epoch:', '0030', 'training time (minutes)=', '0.0142', 'loss=', '0.061188086')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-30 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0031', 'training time (minutes)=', '0.0142', 'loss=', '0.060036415')
# ('Epoch:', '0032', 'training time (minutes)=', '0.0142', 'loss=', '0.060059721')
# ('Epoch:', '0033', 'training time (minutes)=', '0.0142', 'loss=', '0.061673812')
# ('Epoch:', '0034', 'training time (minutes)=', '0.0141', 'loss=', '0.060633699')
# ('Epoch:', '0035', 'training time (minutes)=', '0.0147', 'loss=', '0.058657463')
# ('Epoch:', '0036', 'training time (minutes)=', '0.0142', 'loss=', '0.059419207')
# ('Epoch:', '0037', 'training time (minutes)=', '0.0142', 'loss=', '0.062096101')
# ('Epoch:', '0038', 'training time (minutes)=', '0.0145', 'loss=', '0.058236820')
# ('Epoch:', '0039', 'training time (minutes)=', '0.0142', 'loss=', '0.058492290')
# ('Epoch:', '0040', 'training time (minutes)=', '0.0142', 'loss=', '0.059056618')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-40 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0041', 'training time (minutes)=', '0.0142', 'loss=', '0.057982498')
# ('Epoch:', '0042', 'training time (minutes)=', '0.0144', 'loss=', '0.059845109')
# ('Epoch:', '0043', 'training time (minutes)=', '0.0146', 'loss=', '0.057709259')
# ('Epoch:', '0044', 'training time (minutes)=', '0.0148', 'loss=', '0.057008933')
# ('Epoch:', '0045', 'training time (minutes)=', '0.0149', 'loss=', '0.056779210')
# ('Epoch:', '0046', 'training time (minutes)=', '0.0156', 'loss=', '0.057076932')
# ('Epoch:', '0047', 'training time (minutes)=', '0.0143', 'loss=', '0.058906324')
# ('Epoch:', '0048', 'training time (minutes)=', '0.0143', 'loss=', '0.059876193')
# ('Epoch:', '0049', 'training time (minutes)=', '0.0144', 'loss=', '0.057953337')
# ('Epoch:', '0050', 'training time (minutes)=', '0.0147', 'loss=', '0.056842412')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-50 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0051', 'training time (minutes)=', '0.0144', 'loss=', '0.057074234')
# ('Epoch:', '0052', 'training time (minutes)=', '0.0145', 'loss=', '0.056682499')
# ('Epoch:', '0053', 'training time (minutes)=', '0.0149', 'loss=', '0.056429612')
# ('Epoch:', '0054', 'training time (minutes)=', '0.0145', 'loss=', '0.056358065')
# ('Epoch:', '0055', 'training time (minutes)=', '0.0144', 'loss=', '0.056607806')
# ('Epoch:', '0056', 'training time (minutes)=', '0.0143', 'loss=', '0.056077113')
# ('Epoch:', '0057', 'training time (minutes)=', '0.0144', 'loss=', '0.059209009')
# ('Epoch:', '0058', 'training time (minutes)=', '0.0144', 'loss=', '0.057026703')
# ('Epoch:', '0059', 'training time (minutes)=', '0.0142', 'loss=', '0.058039971')
# ('Epoch:', '0060', 'training time (minutes)=', '0.0142', 'loss=', '0.055089326')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-60 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0061', 'training time (minutes)=', '0.0141', 'loss=', '0.056330968')
# ('Epoch:', '0062', 'training time (minutes)=', '0.0142', 'loss=', '0.055258509')
# ('Epoch:', '0063', 'training time (minutes)=', '0.0142', 'loss=', '0.056075159')
# ('Epoch:', '0064', 'training time (minutes)=', '0.0142', 'loss=', '0.054518752')
# ('Epoch:', '0065', 'training time (minutes)=', '0.0143', 'loss=', '0.057673669')
# ('Epoch:', '0066', 'training time (minutes)=', '0.0145', 'loss=', '0.055853029')
# ('Epoch:', '0067', 'training time (minutes)=', '0.0145', 'loss=', '0.056582986')
# ('Epoch:', '0068', 'training time (minutes)=', '0.0146', 'loss=', '0.056299054')
# ('Epoch:', '0069', 'training time (minutes)=', '0.0145', 'loss=', '0.053876583')
# ('Epoch:', '0070', 'training time (minutes)=', '0.0147', 'loss=', '0.054005563')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-70 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0071', 'training time (minutes)=', '0.0146', 'loss=', '0.053692956')
# ('Epoch:', '0072', 'training time (minutes)=', '0.0145', 'loss=', '0.053471291')
# ('Epoch:', '0073', 'training time (minutes)=', '0.0143', 'loss=', '0.053780382')
# ('Epoch:', '0074', 'training time (minutes)=', '0.0143', 'loss=', '0.055501871')
# ('Epoch:', '0075', 'training time (minutes)=', '0.0143', 'loss=', '0.054609093')
# ('Epoch:', '0076', 'training time (minutes)=', '0.0143', 'loss=', '0.054135242')
# ('Epoch:', '0077', 'training time (minutes)=', '0.0145', 'loss=', '0.052520857')
# ('Epoch:', '0078', 'training time (minutes)=', '0.0147', 'loss=', '0.053077162')
# ('Epoch:', '0079', 'training time (minutes)=', '0.0147', 'loss=', '0.051801745')
# ('Epoch:', '0080', 'training time (minutes)=', '0.0149', 'loss=', '0.052176660')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-80 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0081', 'training time (minutes)=', '0.0143', 'loss=', '0.053339373')
# ('Epoch:', '0082', 'training time (minutes)=', '0.0142', 'loss=', '0.051398830')
# ('Epoch:', '0083', 'training time (minutes)=', '0.0143', 'loss=', '0.051924734')
# ('Epoch:', '0084', 'training time (minutes)=', '0.0143', 'loss=', '0.051796429')
# ('Epoch:', '0085', 'training time (minutes)=', '0.0143', 'loss=', '0.053092729')
# ('Epoch:', '0086', 'training time (minutes)=', '0.0143', 'loss=', '0.051685571')
# ('Epoch:', '0087', 'training time (minutes)=', '0.0143', 'loss=', '0.052241108')
# ('Epoch:', '0088', 'training time (minutes)=', '0.0142', 'loss=', '0.051615412')
# ('Epoch:', '0089', 'training time (minutes)=', '0.0142', 'loss=', '0.052216399')
# ('Epoch:', '0090', 'training time (minutes)=', '0.0142', 'loss=', '0.051272362')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-90 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0091', 'training time (minutes)=', '0.0143', 'loss=', '0.053617127')
# ('Epoch:', '0092', 'training time (minutes)=', '0.0143', 'loss=', '0.049582812')
# ('Epoch:', '0093', 'training time (minutes)=', '0.0143', 'loss=', '0.051507382')
# ('Epoch:', '0094', 'training time (minutes)=', '0.0143', 'loss=', '0.049894951')
# ('Epoch:', '0095', 'training time (minutes)=', '0.0143', 'loss=', '0.051398999')
# ('Epoch:', '0096', 'training time (minutes)=', '0.0143', 'loss=', '0.050284496')
# ('Epoch:', '0097', 'training time (minutes)=', '0.0142', 'loss=', '0.049760585')
# ('Epoch:', '0098', 'training time (minutes)=', '0.0143', 'loss=', '0.049790050')
# ('Epoch:', '0099', 'training time (minutes)=', '0.0142', 'loss=', '0.050530102')
# ('Epoch:', '0100', 'training time (minutes)=', '0.0143', 'loss=', '0.049639918')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-100 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0101', 'training time (minutes)=', '0.0147', 'loss=', '0.048318645')
# ('Epoch:', '0102', 'training time (minutes)=', '0.0142', 'loss=', '0.050417982')
# ('Epoch:', '0103', 'training time (minutes)=', '0.0143', 'loss=', '0.050598204')
# ('Epoch:', '0104', 'training time (minutes)=', '0.0144', 'loss=', '0.052040040')
# ('Epoch:', '0105', 'training time (minutes)=', '0.0143', 'loss=', '0.052497748')
# ('Epoch:', '0106', 'training time (minutes)=', '0.0143', 'loss=', '0.051097531')
# ('Epoch:', '0107', 'training time (minutes)=', '0.0143', 'loss=', '0.050911505')
# ('Epoch:', '0108', 'training time (minutes)=', '0.0143', 'loss=', '0.051176168')
# ('Epoch:', '0109', 'training time (minutes)=', '0.0142', 'loss=', '0.048433702')
# ('Epoch:', '0110', 'training time (minutes)=', '0.0144', 'loss=', '0.048558692')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-110 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0111', 'training time (minutes)=', '0.0147', 'loss=', '0.047466538')
# ('Epoch:', '0112', 'training time (minutes)=', '0.0145', 'loss=', '0.048349634')
# ('Epoch:', '0113', 'training time (minutes)=', '0.0146', 'loss=', '0.048207466')
# ('Epoch:', '0114', 'training time (minutes)=', '0.0146', 'loss=', '0.047211507')
# ('Epoch:', '0115', 'training time (minutes)=', '0.0146', 'loss=', '0.047662226')
# ('Epoch:', '0116', 'training time (minutes)=', '0.0146', 'loss=', '0.047155577')
# ('Epoch:', '0117', 'training time (minutes)=', '0.0146', 'loss=', '0.047450303')
# ('Epoch:', '0118', 'training time (minutes)=', '0.0146', 'loss=', '0.048714174')
# ('Epoch:', '0119', 'training time (minutes)=', '0.0146', 'loss=', '0.049000192')
# ('Epoch:', '0120', 'training time (minutes)=', '0.0145', 'loss=', '0.048247633')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-120 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0121', 'training time (minutes)=', '0.0145', 'loss=', '0.048585506')
# ('Epoch:', '0122', 'training time (minutes)=', '0.0144', 'loss=', '0.046711092')
# ('Epoch:', '0123', 'training time (minutes)=', '0.0144', 'loss=', '0.047096191')
# ('Epoch:', '0124', 'training time (minutes)=', '0.0144', 'loss=', '0.047149493')
# ('Epoch:', '0125', 'training time (minutes)=', '0.0144', 'loss=', '0.048377479')
# ('Epoch:', '0126', 'training time (minutes)=', '0.0144', 'loss=', '0.049515113')
# ('Epoch:', '0127', 'training time (minutes)=', '0.0144', 'loss=', '0.048293858')
# ('Epoch:', '0128', 'training time (minutes)=', '0.0143', 'loss=', '0.048066678')
# ('Epoch:', '0129', 'training time (minutes)=', '0.0143', 'loss=', '0.048343726')
# ('Epoch:', '0130', 'training time (minutes)=', '0.0143', 'loss=', '0.048028018')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-130 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0131', 'training time (minutes)=', '0.0144', 'loss=', '0.046620040')
# ('Epoch:', '0132', 'training time (minutes)=', '0.0143', 'loss=', '0.048604197')
# ('Epoch:', '0133', 'training time (minutes)=', '0.0143', 'loss=', '0.048879065')
# ('Epoch:', '0134', 'training time (minutes)=', '0.0143', 'loss=', '0.050191924')
# ('Epoch:', '0135', 'training time (minutes)=', '0.0143', 'loss=', '0.049070104')
# ('Epoch:', '0136', 'training time (minutes)=', '0.0143', 'loss=', '0.048363250')
# ('Epoch:', '0137', 'training time (minutes)=', '0.0143', 'loss=', '0.048347480')
# ('Epoch:', '0138', 'training time (minutes)=', '0.0142', 'loss=', '0.048499355')
# ('Epoch:', '0139', 'training time (minutes)=', '0.0143', 'loss=', '0.048385407')
# ('Epoch:', '0140', 'training time (minutes)=', '0.0143', 'loss=', '0.049675540')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-140 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0141', 'training time (minutes)=', '0.0143', 'loss=', '0.048897513')
# ('Epoch:', '0142', 'training time (minutes)=', '0.0144', 'loss=', '0.047869117')
# ('Epoch:', '0143', 'training time (minutes)=', '0.0143', 'loss=', '0.048026267')
# ('Epoch:', '0144', 'training time (minutes)=', '0.0144', 'loss=', '0.046801193')
# ('Epoch:', '0145', 'training time (minutes)=', '0.0143', 'loss=', '0.046718595')
# ('Epoch:', '0146', 'training time (minutes)=', '0.0145', 'loss=', '0.046313797')
# ('Epoch:', '0147', 'training time (minutes)=', '0.0143', 'loss=', '0.047500801')
# ('Epoch:', '0148', 'training time (minutes)=', '0.0143', 'loss=', '0.047294006')
# ('Epoch:', '0149', 'training time (minutes)=', '0.0143', 'loss=', '0.047588949')
# ('Epoch:', '0150', 'training time (minutes)=', '0.0143', 'loss=', '0.046854396')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-150 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0151', 'training time (minutes)=', '0.0144', 'loss=', '0.046485802')
# ('Epoch:', '0152', 'training time (minutes)=', '0.0142', 'loss=', '0.046271478')
# ('Epoch:', '0153', 'training time (minutes)=', '0.0143', 'loss=', '0.045669092')
# ('Epoch:', '0154', 'training time (minutes)=', '0.0143', 'loss=', '0.046804180')
# ('Epoch:', '0155', 'training time (minutes)=', '0.0142', 'loss=', '0.046570305')
# ('Epoch:', '0156', 'training time (minutes)=', '0.0143', 'loss=', '0.046705663')
# ('Epoch:', '0157', 'training time (minutes)=', '0.0142', 'loss=', '0.045877703')
# ('Epoch:', '0158', 'training time (minutes)=', '0.0143', 'loss=', '0.045171411')
# ('Epoch:', '0159', 'training time (minutes)=', '0.0143', 'loss=', '0.045668462')
# ('Epoch:', '0160', 'training time (minutes)=', '0.0143', 'loss=', '0.046181163')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-160 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0161', 'training time (minutes)=', '0.0143', 'loss=', '0.045970947')
# ('Epoch:', '0162', 'training time (minutes)=', '0.0143', 'loss=', '0.046931201')
# ('Epoch:', '0163', 'training time (minutes)=', '0.0143', 'loss=', '0.045584997')
# ('Epoch:', '0164', 'training time (minutes)=', '0.0143', 'loss=', '0.045499605')
# ('Epoch:', '0165', 'training time (minutes)=', '0.0143', 'loss=', '0.047317726')
# ('Epoch:', '0166', 'training time (minutes)=', '0.0143', 'loss=', '0.046188132')
# ('Epoch:', '0167', 'training time (minutes)=', '0.0142', 'loss=', '0.045865888')
# ('Epoch:', '0168', 'training time (minutes)=', '0.0143', 'loss=', '0.046687512')
# ('Epoch:', '0169', 'training time (minutes)=', '0.0144', 'loss=', '0.046459933')
# ('Epoch:', '0170', 'training time (minutes)=', '0.0145', 'loss=', '0.045335510')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-170 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0171', 'training time (minutes)=', '0.0144', 'loss=', '0.048479131')
# ('Epoch:', '0172', 'training time (minutes)=', '0.0149', 'loss=', '0.045981650')
# ('Epoch:', '0173', 'training time (minutes)=', '0.0150', 'loss=', '0.044754218')
# ('Epoch:', '0174', 'training time (minutes)=', '0.0147', 'loss=', '0.044529074')
# ('Epoch:', '0175', 'training time (minutes)=', '0.0151', 'loss=', '0.045988231')
# ('Epoch:', '0176', 'training time (minutes)=', '0.0150', 'loss=', '0.045017023')
# ('Epoch:', '0177', 'training time (minutes)=', '0.0147', 'loss=', '0.046197752')
# ('Epoch:', '0178', 'training time (minutes)=', '0.0143', 'loss=', '0.046069730')
# ('Epoch:', '0179', 'training time (minutes)=', '0.0148', 'loss=', '0.046263642')
# ('Epoch:', '0180', 'training time (minutes)=', '0.0144', 'loss=', '0.046097095')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-180 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0181', 'training time (minutes)=', '0.0144', 'loss=', '0.047620622')
# ('Epoch:', '0182', 'training time (minutes)=', '0.0148', 'loss=', '0.048987727')
# ('Epoch:', '0183', 'training time (minutes)=', '0.0143', 'loss=', '0.046972030')
# ('Epoch:', '0184', 'training time (minutes)=', '0.0144', 'loss=', '0.046553260')
# ('Epoch:', '0185', 'training time (minutes)=', '0.0143', 'loss=', '0.047216867')
# ('Epoch:', '0186', 'training time (minutes)=', '0.0144', 'loss=', '0.046364038')
# ('Epoch:', '0187', 'training time (minutes)=', '0.0144', 'loss=', '0.045390004')
# ('Epoch:', '0188', 'training time (minutes)=', '0.0144', 'loss=', '0.046094863')
# ('Epoch:', '0189', 'training time (minutes)=', '0.0144', 'loss=', '0.045461975')
# ('Epoch:', '0190', 'training time (minutes)=', '0.0143', 'loss=', '0.045754695')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-190 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0191', 'training time (minutes)=', '0.0148', 'loss=', '0.044618709')
# ('Epoch:', '0192', 'training time (minutes)=', '0.0143', 'loss=', '0.044648534')
# ('Epoch:', '0193', 'training time (minutes)=', '0.0144', 'loss=', '0.043938192')
# ('Epoch:', '0194', 'training time (minutes)=', '0.0142', 'loss=', '0.044082128')
# ('Epoch:', '0195', 'training time (minutes)=', '0.0144', 'loss=', '0.043570288')
# ('Epoch:', '0196', 'training time (minutes)=', '0.0144', 'loss=', '0.043924048')
# ('Epoch:', '0197', 'training time (minutes)=', '0.0143', 'loss=', '0.043438503')
# ('Epoch:', '0198', 'training time (minutes)=', '0.0144', 'loss=', '0.045235462')
# ('Epoch:', '0199', 'training time (minutes)=', '0.0143', 'loss=', '0.044843364')
# ('Epoch:', '0200', 'training time (minutes)=', '0.0143', 'loss=', '0.044169672')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-200 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0201', 'training time (minutes)=', '0.0144', 'loss=', '0.043753476')
# ('Epoch:', '0202', 'training time (minutes)=', '0.0143', 'loss=', '0.043993337')
# ('Epoch:', '0203', 'training time (minutes)=', '0.0147', 'loss=', '0.045406616')
# ('Epoch:', '0204', 'training time (minutes)=', '0.0143', 'loss=', '0.044045788')
# ('Epoch:', '0205', 'training time (minutes)=', '0.0144', 'loss=', '0.044394278')
# ('Epoch:', '0206', 'training time (minutes)=', '0.0144', 'loss=', '0.043887766')
# ('Epoch:', '0207', 'training time (minutes)=', '0.0143', 'loss=', '0.044292510')
# ('Epoch:', '0208', 'training time (minutes)=', '0.0143', 'loss=', '0.043534647')
# ('Epoch:', '0209', 'training time (minutes)=', '0.0145', 'loss=', '0.043763624')
# ('Epoch:', '0210', 'training time (minutes)=', '0.0145', 'loss=', '0.044976284')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-210 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0211', 'training time (minutes)=', '0.0145', 'loss=', '0.044269028')
# ('Epoch:', '0212', 'training time (minutes)=', '0.0143', 'loss=', '0.046032057')
# ('Epoch:', '0213', 'training time (minutes)=', '0.0142', 'loss=', '0.044302342')
# ('Epoch:', '0214', 'training time (minutes)=', '0.0144', 'loss=', '0.044056434')
# ('Epoch:', '0215', 'training time (minutes)=', '0.0144', 'loss=', '0.044216466')
# ('Epoch:', '0216', 'training time (minutes)=', '0.0144', 'loss=', '0.043374620')
# ('Epoch:', '0217', 'training time (minutes)=', '0.0143', 'loss=', '0.043344464')
# ('Epoch:', '0218', 'training time (minutes)=', '0.0143', 'loss=', '0.044325328')
# ('Epoch:', '0219', 'training time (minutes)=', '0.0143', 'loss=', '0.043183780')
# ('Epoch:', '0220', 'training time (minutes)=', '0.0144', 'loss=', '0.044820432')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-220 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0221', 'training time (minutes)=', '0.0144', 'loss=', '0.043519276')
# ('Epoch:', '0222', 'training time (minutes)=', '0.0143', 'loss=', '0.044269264')
# ('Epoch:', '0223', 'training time (minutes)=', '0.0144', 'loss=', '0.044017293')
# ('Epoch:', '0224', 'training time (minutes)=', '0.0143', 'loss=', '0.044654028')
# ('Epoch:', '0225', 'training time (minutes)=', '0.0142', 'loss=', '0.044189836')
# ('Epoch:', '0226', 'training time (minutes)=', '0.0142', 'loss=', '0.043942605')
# ('Epoch:', '0227', 'training time (minutes)=', '0.0143', 'loss=', '0.043402431')
# ('Epoch:', '0228', 'training time (minutes)=', '0.0143', 'loss=', '0.042812135')
# ('Epoch:', '0229', 'training time (minutes)=', '0.0143', 'loss=', '0.042988371')
# ('Epoch:', '0230', 'training time (minutes)=', '0.0143', 'loss=', '0.041686099')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-230 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0231', 'training time (minutes)=', '0.0143', 'loss=', '0.041990642')
# ('Epoch:', '0232', 'training time (minutes)=', '0.0143', 'loss=', '0.043242325')
# ('Epoch:', '0233', 'training time (minutes)=', '0.0143', 'loss=', '0.042046828')
# ('Epoch:', '0234', 'training time (minutes)=', '0.0143', 'loss=', '0.043156337')
# ('Epoch:', '0235', 'training time (minutes)=', '0.0142', 'loss=', '0.042621618')
# ('Epoch:', '0236', 'training time (minutes)=', '0.0142', 'loss=', '0.042253683')
# ('Epoch:', '0237', 'training time (minutes)=', '0.0143', 'loss=', '0.042898234')
# ('Epoch:', '0238', 'training time (minutes)=', '0.0142', 'loss=', '0.044103669')
# ('Epoch:', '0239', 'training time (minutes)=', '0.0143', 'loss=', '0.044918393')
# ('Epoch:', '0240', 'training time (minutes)=', '0.0142', 'loss=', '0.043101629')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-240 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0241', 'training time (minutes)=', '0.0143', 'loss=', '0.043446220')
# ('Epoch:', '0242', 'training time (minutes)=', '0.0143', 'loss=', '0.042726259')
# ('Epoch:', '0243', 'training time (minutes)=', '0.0143', 'loss=', '0.043608784')
# ('Epoch:', '0244', 'training time (minutes)=', '0.0142', 'loss=', '0.043793319')
# ('Epoch:', '0245', 'training time (minutes)=', '0.0143', 'loss=', '0.042783597')
# ('Epoch:', '0246', 'training time (minutes)=', '0.0143', 'loss=', '0.043211447')
# ('Epoch:', '0247', 'training time (minutes)=', '0.0142', 'loss=', '0.043156595')
# ('Epoch:', '0248', 'training time (minutes)=', '0.0143', 'loss=', '0.043999703')
# ('Epoch:', '0249', 'training time (minutes)=', '0.0142', 'loss=', '0.042828728')
# ('Epoch:', '0250', 'training time (minutes)=', '0.0143', 'loss=', '0.042918694')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-250 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0251', 'training time (minutes)=', '0.0143', 'loss=', '0.042749031')
# ('Epoch:', '0252', 'training time (minutes)=', '0.0143', 'loss=', '0.043449622')
# ('Epoch:', '0253', 'training time (minutes)=', '0.0143', 'loss=', '0.041566151')
# ('Epoch:', '0254', 'training time (minutes)=', '0.0142', 'loss=', '0.043626402')
# ('Epoch:', '0255', 'training time (minutes)=', '0.0143', 'loss=', '0.043595885')
# ('Epoch:', '0256', 'training time (minutes)=', '0.0143', 'loss=', '0.041715165')
# ('Epoch:', '0257', 'training time (minutes)=', '0.0142', 'loss=', '0.042787687')
# ('Epoch:', '0258', 'training time (minutes)=', '0.0143', 'loss=', '0.042738108')
# ('Epoch:', '0259', 'training time (minutes)=', '0.0143', 'loss=', '0.043208487')
# ('Epoch:', '0260', 'training time (minutes)=', '0.0143', 'loss=', '0.046512340')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-260 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0261', 'training time (minutes)=', '0.0143', 'loss=', '0.042737033')
# ('Epoch:', '0262', 'training time (minutes)=', '0.0142', 'loss=', '0.043409957')
# ('Epoch:', '0263', 'training time (minutes)=', '0.0143', 'loss=', '0.043699598')
# ('Epoch:', '0264', 'training time (minutes)=', '0.0143', 'loss=', '0.042227778')
# ('Epoch:', '0265', 'training time (minutes)=', '0.0143', 'loss=', '0.041503545')
# ('Epoch:', '0266', 'training time (minutes)=', '0.0143', 'loss=', '0.042887544')
# ('Epoch:', '0267', 'training time (minutes)=', '0.0143', 'loss=', '0.042205444')
# ('Epoch:', '0268', 'training time (minutes)=', '0.0142', 'loss=', '0.040912317')
# ('Epoch:', '0269', 'training time (minutes)=', '0.0142', 'loss=', '0.041809397')
# ('Epoch:', '0270', 'training time (minutes)=', '0.0142', 'loss=', '0.041204818')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-270 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0271', 'training time (minutes)=', '0.0143', 'loss=', '0.041122732')
# ('Epoch:', '0272', 'training time (minutes)=', '0.0142', 'loss=', '0.040275502')
# ('Epoch:', '0273', 'training time (minutes)=', '0.0142', 'loss=', '0.040271000')
# ('Epoch:', '0274', 'training time (minutes)=', '0.0143', 'loss=', '0.039983680')
# ('Epoch:', '0275', 'training time (minutes)=', '0.0142', 'loss=', '0.040726016')
# ('Epoch:', '0276', 'training time (minutes)=', '0.0143', 'loss=', '0.040860582')
# ('Epoch:', '0277', 'training time (minutes)=', '0.0144', 'loss=', '0.042374151')
# ('Epoch:', '0278', 'training time (minutes)=', '0.0142', 'loss=', '0.042300604')
# ('Epoch:', '0279', 'training time (minutes)=', '0.0145', 'loss=', '0.041404421')
# ('Epoch:', '0280', 'training time (minutes)=', '0.0143', 'loss=', '0.041637177')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-280 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0281', 'training time (minutes)=', '0.0144', 'loss=', '0.040799137')
# ('Epoch:', '0282', 'training time (minutes)=', '0.0143', 'loss=', '0.042365480')
# ('Epoch:', '0283', 'training time (minutes)=', '0.0143', 'loss=', '0.040709045')
# ('Epoch:', '0284', 'training time (minutes)=', '0.0142', 'loss=', '0.040676415')
# ('Epoch:', '0285', 'training time (minutes)=', '0.0143', 'loss=', '0.041342529')
# ('Epoch:', '0286', 'training time (minutes)=', '0.0143', 'loss=', '0.041018196')
# ('Epoch:', '0287', 'training time (minutes)=', '0.0142', 'loss=', '0.040639837')
# ('Epoch:', '0288', 'training time (minutes)=', '0.0143', 'loss=', '0.040033199')
# ('Epoch:', '0289', 'training time (minutes)=', '0.0142', 'loss=', '0.041082215')
# ('Epoch:', '0290', 'training time (minutes)=', '0.0142', 'loss=', '0.040484558')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-290 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0291', 'training time (minutes)=', '0.0144', 'loss=', '0.041162945')
# ('Epoch:', '0292', 'training time (minutes)=', '0.0143', 'loss=', '0.040659581')
# ('Epoch:', '0293', 'training time (minutes)=', '0.0142', 'loss=', '0.041475214')
# ('Epoch:', '0294', 'training time (minutes)=', '0.0142', 'loss=', '0.040582963')
# ('Epoch:', '0295', 'training time (minutes)=', '0.0142', 'loss=', '0.041854423')
# ('Epoch:', '0296', 'training time (minutes)=', '0.0143', 'loss=', '0.041903076')
# ('Epoch:', '0297', 'training time (minutes)=', '0.0143', 'loss=', '0.040850033')
# ('Epoch:', '0298', 'training time (minutes)=', '0.0143', 'loss=', '0.040506833')
# ('Epoch:', '0299', 'training time (minutes)=', '0.0142', 'loss=', '0.042449437')
# ('Epoch:', '0300', 'training time (minutes)=', '0.0143', 'loss=', '0.040576711')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-300 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0301', 'training time (minutes)=', '0.0144', 'loss=', '0.041444504')
# ('Epoch:', '0302', 'training time (minutes)=', '0.0142', 'loss=', '0.041329365')
# ('Epoch:', '0303', 'training time (minutes)=', '0.0142', 'loss=', '0.041960801')
# ('Epoch:', '0304', 'training time (minutes)=', '0.0142', 'loss=', '0.041963614')
# ('Epoch:', '0305', 'training time (minutes)=', '0.0143', 'loss=', '0.041219565')
# ('Epoch:', '0306', 'training time (minutes)=', '0.0142', 'loss=', '0.040532856')
# ('Epoch:', '0307', 'training time (minutes)=', '0.0143', 'loss=', '0.040419598')
# ('Epoch:', '0308', 'training time (minutes)=', '0.0142', 'loss=', '0.040564377')
# ('Epoch:', '0309', 'training time (minutes)=', '0.0142', 'loss=', '0.040555709')
# ('Epoch:', '0310', 'training time (minutes)=', '0.0143', 'loss=', '0.042524694')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-310 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0311', 'training time (minutes)=', '0.0144', 'loss=', '0.042215058')
# ('Epoch:', '0312', 'training time (minutes)=', '0.0142', 'loss=', '0.042442748')
# ('Epoch:', '0313', 'training time (minutes)=', '0.0143', 'loss=', '0.042140875')
# ('Epoch:', '0314', 'training time (minutes)=', '0.0142', 'loss=', '0.040478748')
# ('Epoch:', '0315', 'training time (minutes)=', '0.0146', 'loss=', '0.040969850')
# ('Epoch:', '0316', 'training time (minutes)=', '0.0144', 'loss=', '0.040678871')
# ('Epoch:', '0317', 'training time (minutes)=', '0.0144', 'loss=', '0.040019083')
# ('Epoch:', '0318', 'training time (minutes)=', '0.0143', 'loss=', '0.041035106')
# ('Epoch:', '0319', 'training time (minutes)=', '0.0143', 'loss=', '0.041599129')
# ('Epoch:', '0320', 'training time (minutes)=', '0.0143', 'loss=', '0.041985147')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-320 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0321', 'training time (minutes)=', '0.0145', 'loss=', '0.039396266')
# ('Epoch:', '0322', 'training time (minutes)=', '0.0143', 'loss=', '0.039692556')
# ('Epoch:', '0323', 'training time (minutes)=', '0.0145', 'loss=', '0.039821721')
# ('Epoch:', '0324', 'training time (minutes)=', '0.0144', 'loss=', '0.040272647')
# ('Epoch:', '0325', 'training time (minutes)=', '0.0143', 'loss=', '0.041008937')
# ('Epoch:', '0326', 'training time (minutes)=', '0.0143', 'loss=', '0.039569044')
# ('Epoch:', '0327', 'training time (minutes)=', '0.0143', 'loss=', '0.040288551')
# ('Epoch:', '0328', 'training time (minutes)=', '0.0144', 'loss=', '0.040014014')
# ('Epoch:', '0329', 'training time (minutes)=', '0.0142', 'loss=', '0.039039064')
# ('Epoch:', '0330', 'training time (minutes)=', '0.0144', 'loss=', '0.039692745')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-330 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0331', 'training time (minutes)=', '0.0143', 'loss=', '0.039185725')
# ('Epoch:', '0332', 'training time (minutes)=', '0.0143', 'loss=', '0.040756688')
# ('Epoch:', '0333', 'training time (minutes)=', '0.0143', 'loss=', '0.040487478')
# ('Epoch:', '0334', 'training time (minutes)=', '0.0142', 'loss=', '0.039958881')
# ('Epoch:', '0335', 'training time (minutes)=', '0.0144', 'loss=', '0.039475690')
# ('Epoch:', '0336', 'training time (minutes)=', '0.0143', 'loss=', '0.041098681')
# ('Epoch:', '0337', 'training time (minutes)=', '0.0143', 'loss=', '0.039046424')
# ('Epoch:', '0338', 'training time (minutes)=', '0.0143', 'loss=', '0.039363652')
# ('Epoch:', '0339', 'training time (minutes)=', '0.0142', 'loss=', '0.040638613')
# ('Epoch:', '0340', 'training time (minutes)=', '0.0142', 'loss=', '0.039548598')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-340 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0341', 'training time (minutes)=', '0.0144', 'loss=', '0.039525780')
# ('Epoch:', '0342', 'training time (minutes)=', '0.0144', 'loss=', '0.040219444')
# ('Epoch:', '0343', 'training time (minutes)=', '0.0142', 'loss=', '0.040961152')
# ('Epoch:', '0344', 'training time (minutes)=', '0.0143', 'loss=', '0.038614430')
# ('Epoch:', '0345', 'training time (minutes)=', '0.0143', 'loss=', '0.039053041')
# ('Epoch:', '0346', 'training time (minutes)=', '0.0143', 'loss=', '0.039905610')
# ('Epoch:', '0347', 'training time (minutes)=', '0.0142', 'loss=', '0.039429699')
# ('Epoch:', '0348', 'training time (minutes)=', '0.0143', 'loss=', '0.041346590')
# ('Epoch:', '0349', 'training time (minutes)=', '0.0144', 'loss=', '0.040179669')
# ('Epoch:', '0350', 'training time (minutes)=', '0.0149', 'loss=', '0.040471766')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-350 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0351', 'training time (minutes)=', '0.0152', 'loss=', '0.038778966')
# ('Epoch:', '0352', 'training time (minutes)=', '0.0149', 'loss=', '0.040416704')
# ('Epoch:', '0353', 'training time (minutes)=', '0.0150', 'loss=', '0.039307822')
# ('Epoch:', '0354', 'training time (minutes)=', '0.0145', 'loss=', '0.038787062')
# ('Epoch:', '0355', 'training time (minutes)=', '0.0144', 'loss=', '0.038753998')
# ('Epoch:', '0356', 'training time (minutes)=', '0.0143', 'loss=', '0.040256729')
# ('Epoch:', '0357', 'training time (minutes)=', '0.0143', 'loss=', '0.039971767')
# ('Epoch:', '0358', 'training time (minutes)=', '0.0143', 'loss=', '0.039000015')
# ('Epoch:', '0359', 'training time (minutes)=', '0.0143', 'loss=', '0.039894435')
# ('Epoch:', '0360', 'training time (minutes)=', '0.0142', 'loss=', '0.041130096')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-360 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0361', 'training time (minutes)=', '0.0143', 'loss=', '0.039660877')
# ('Epoch:', '0362', 'training time (minutes)=', '0.0143', 'loss=', '0.039788844')
# ('Epoch:', '0363', 'training time (minutes)=', '0.0143', 'loss=', '0.039778339')
# ('Epoch:', '0364', 'training time (minutes)=', '0.0142', 'loss=', '0.040421407')
# ('Epoch:', '0365', 'training time (minutes)=', '0.0143', 'loss=', '0.040165769')
# ('Epoch:', '0366', 'training time (minutes)=', '0.0142', 'loss=', '0.040907658')
# ('Epoch:', '0367', 'training time (minutes)=', '0.0142', 'loss=', '0.039403600')
# ('Epoch:', '0368', 'training time (minutes)=', '0.0143', 'loss=', '0.038891003')
# ('Epoch:', '0369', 'training time (minutes)=', '0.0143', 'loss=', '0.039257010')
# ('Epoch:', '0370', 'training time (minutes)=', '0.0142', 'loss=', '0.039783675')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-370 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0371', 'training time (minutes)=', '0.0142', 'loss=', '0.038895609')
# ('Epoch:', '0372', 'training time (minutes)=', '0.0143', 'loss=', '0.039620113')
# ('Epoch:', '0373', 'training time (minutes)=', '0.0142', 'loss=', '0.038785832')
# ('Epoch:', '0374', 'training time (minutes)=', '0.0142', 'loss=', '0.039200841')
# ('Epoch:', '0375', 'training time (minutes)=', '0.0143', 'loss=', '0.040173282')
# ('Epoch:', '0376', 'training time (minutes)=', '0.0143', 'loss=', '0.039548435')
# ('Epoch:', '0377', 'training time (minutes)=', '0.0142', 'loss=', '0.040820395')
# ('Epoch:', '0378', 'training time (minutes)=', '0.0142', 'loss=', '0.039613580')
# ('Epoch:', '0379', 'training time (minutes)=', '0.0143', 'loss=', '0.039223495')
# ('Epoch:', '0380', 'training time (minutes)=', '0.0142', 'loss=', '0.038868382')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-380 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0381', 'training time (minutes)=', '0.0144', 'loss=', '0.038874503')
# ('Epoch:', '0382', 'training time (minutes)=', '0.0142', 'loss=', '0.038848632')
# ('Epoch:', '0383', 'training time (minutes)=', '0.0142', 'loss=', '0.039733616')
# ('Epoch:', '0384', 'training time (minutes)=', '0.0143', 'loss=', '0.039062336')
# ('Epoch:', '0385', 'training time (minutes)=', '0.0142', 'loss=', '0.039092596')
# ('Epoch:', '0386', 'training time (minutes)=', '0.0142', 'loss=', '0.039631989')
# ('Epoch:', '0387', 'training time (minutes)=', '0.0142', 'loss=', '0.041925814')
# ('Epoch:', '0388', 'training time (minutes)=', '0.0143', 'loss=', '0.040260067')
# ('Epoch:', '0389', 'training time (minutes)=', '0.0142', 'loss=', '0.039793547')
# ('Epoch:', '0390', 'training time (minutes)=', '0.0143', 'loss=', '0.039175843')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-390 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0391', 'training time (minutes)=', '0.0143', 'loss=', '0.039225602')
# ('Epoch:', '0392', 'training time (minutes)=', '0.0142', 'loss=', '0.038276734')
# ('Epoch:', '0393', 'training time (minutes)=', '0.0142', 'loss=', '0.038546997')
# ('Epoch:', '0394', 'training time (minutes)=', '0.0142', 'loss=', '0.039219012')
# ('Epoch:', '0395', 'training time (minutes)=', '0.0143', 'loss=', '0.039066617')
# ('Epoch:', '0396', 'training time (minutes)=', '0.0142', 'loss=', '0.037977200')
# ('Epoch:', '0397', 'training time (minutes)=', '0.0142', 'loss=', '0.038888366')
# ('Epoch:', '0398', 'training time (minutes)=', '0.0142', 'loss=', '0.038070685')
# ('Epoch:', '0399', 'training time (minutes)=', '0.0143', 'loss=', '0.037876494')
# ('Epoch:', '0400', 'training time (minutes)=', '0.0142', 'loss=', '0.038958837')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-400 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0401', 'training time (minutes)=', '0.0142', 'loss=', '0.039176594')
# ('Epoch:', '0402', 'training time (minutes)=', '0.0142', 'loss=', '0.038251882')
# ('Epoch:', '0403', 'training time (minutes)=', '0.0143', 'loss=', '0.038479433')
# ('Epoch:', '0404', 'training time (minutes)=', '0.0142', 'loss=', '0.038518823')
# ('Epoch:', '0405', 'training time (minutes)=', '0.0142', 'loss=', '0.039503898')
# ('Epoch:', '0406', 'training time (minutes)=', '0.0142', 'loss=', '0.037895884')
# ('Epoch:', '0407', 'training time (minutes)=', '0.0143', 'loss=', '0.038921135')
# ('Epoch:', '0408', 'training time (minutes)=', '0.0142', 'loss=', '0.038692708')
# ('Epoch:', '0409', 'training time (minutes)=', '0.0142', 'loss=', '0.039204044')
# ('Epoch:', '0410', 'training time (minutes)=', '0.0142', 'loss=', '0.037448120')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-410 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0411', 'training time (minutes)=', '0.0145', 'loss=', '0.038804323')
# ('Epoch:', '0412', 'training time (minutes)=', '0.0142', 'loss=', '0.038539514')
# ('Epoch:', '0413', 'training time (minutes)=', '0.0142', 'loss=', '0.038010014')
# ('Epoch:', '0414', 'training time (minutes)=', '0.0142', 'loss=', '0.037426866')
# ('Epoch:', '0415', 'training time (minutes)=', '0.0142', 'loss=', '0.037527778')
# ('Epoch:', '0416', 'training time (minutes)=', '0.0142', 'loss=', '0.037773564')
# ('Epoch:', '0417', 'training time (minutes)=', '0.0143', 'loss=', '0.037112237')
# ('Epoch:', '0418', 'training time (minutes)=', '0.0142', 'loss=', '0.037491434')
# ('Epoch:', '0419', 'training time (minutes)=', '0.0142', 'loss=', '0.037397686')
# ('Epoch:', '0420', 'training time (minutes)=', '0.0142', 'loss=', '0.037036875')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-420 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0421', 'training time (minutes)=', '0.0144', 'loss=', '0.038316185')
# ('Epoch:', '0422', 'training time (minutes)=', '0.0142', 'loss=', '0.036777865')
# ('Epoch:', '0423', 'training time (minutes)=', '0.0142', 'loss=', '0.036711627')
# ('Epoch:', '0424', 'training time (minutes)=', '0.0142', 'loss=', '0.038664171')
# ('Epoch:', '0425', 'training time (minutes)=', '0.0142', 'loss=', '0.038832326')
# ('Epoch:', '0426', 'training time (minutes)=', '0.0143', 'loss=', '0.037419756')
# ('Epoch:', '0427', 'training time (minutes)=', '0.0142', 'loss=', '0.038206692')
# ('Epoch:', '0428', 'training time (minutes)=', '0.0143', 'loss=', '0.038486014')
# ('Epoch:', '0429', 'training time (minutes)=', '0.0142', 'loss=', '0.039304264')
# ('Epoch:', '0430', 'training time (minutes)=', '0.0142', 'loss=', '0.038215424')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-430 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0431', 'training time (minutes)=', '0.0144', 'loss=', '0.037680675')
# ('Epoch:', '0432', 'training time (minutes)=', '0.0142', 'loss=', '0.039159968')
# ('Epoch:', '0433', 'training time (minutes)=', '0.0142', 'loss=', '0.038381447')
# ('Epoch:', '0434', 'training time (minutes)=', '0.0142', 'loss=', '0.037777121')
# ('Epoch:', '0435', 'training time (minutes)=', '0.0142', 'loss=', '0.038892906')
# ('Epoch:', '0436', 'training time (minutes)=', '0.0142', 'loss=', '0.040175961')
# ('Epoch:', '0437', 'training time (minutes)=', '0.0143', 'loss=', '0.039341045')
# ('Epoch:', '0438', 'training time (minutes)=', '0.0142', 'loss=', '0.039075024')
# ('Epoch:', '0439', 'training time (minutes)=', '0.0142', 'loss=', '0.038404373')
# ('Epoch:', '0440', 'training time (minutes)=', '0.0143', 'loss=', '0.037679042')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-440 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0441', 'training time (minutes)=', '0.0143', 'loss=', '0.038260343')
# ('Epoch:', '0442', 'training time (minutes)=', '0.0142', 'loss=', '0.038311066')
# ('Epoch:', '0443', 'training time (minutes)=', '0.0142', 'loss=', '0.037407486')
# ('Epoch:', '0444', 'training time (minutes)=', '0.0143', 'loss=', '0.037542950')
# ('Epoch:', '0445', 'training time (minutes)=', '0.0142', 'loss=', '0.037781755')
# ('Epoch:', '0446', 'training time (minutes)=', '0.0142', 'loss=', '0.038273783')
# ('Epoch:', '0447', 'training time (minutes)=', '0.0142', 'loss=', '0.037562382')
# ('Epoch:', '0448', 'training time (minutes)=', '0.0142', 'loss=', '0.038003981')
# ('Epoch:', '0449', 'training time (minutes)=', '0.0142', 'loss=', '0.037677480')
# ('Epoch:', '0450', 'training time (minutes)=', '0.0142', 'loss=', '0.038412639')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-450 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0451', 'training time (minutes)=', '0.0144', 'loss=', '0.038796714')
# ('Epoch:', '0452', 'training time (minutes)=', '0.0143', 'loss=', '0.037955489')
# ('Epoch:', '0453', 'training time (minutes)=', '0.0142', 'loss=', '0.037684722')
# ('Epoch:', '0454', 'training time (minutes)=', '0.0142', 'loss=', '0.038403140')
# ('Epoch:', '0455', 'training time (minutes)=', '0.0142', 'loss=', '0.038590075')
# ('Epoch:', '0456', 'training time (minutes)=', '0.0142', 'loss=', '0.039360632')
# ('Epoch:', '0457', 'training time (minutes)=', '0.0143', 'loss=', '0.038617539')
# ('Epoch:', '0458', 'training time (minutes)=', '0.0142', 'loss=', '0.038683557')
# ('Epoch:', '0459', 'training time (minutes)=', '0.0143', 'loss=', '0.038458524')
# ('Epoch:', '0460', 'training time (minutes)=', '0.0142', 'loss=', '0.037531777')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-460 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0461', 'training time (minutes)=', '0.0144', 'loss=', '0.037489145')
# ('Epoch:', '0462', 'training time (minutes)=', '0.0142', 'loss=', '0.039223195')
# ('Epoch:', '0463', 'training time (minutes)=', '0.0143', 'loss=', '0.036982068')
# ('Epoch:', '0464', 'training time (minutes)=', '0.0142', 'loss=', '0.036740483')
# ('Epoch:', '0465', 'training time (minutes)=', '0.0143', 'loss=', '0.036761474')
# ('Epoch:', '0466', 'training time (minutes)=', '0.0142', 'loss=', '0.036514352')
# ('Epoch:', '0467', 'training time (minutes)=', '0.0143', 'loss=', '0.037350106')
# ('Epoch:', '0468', 'training time (minutes)=', '0.0142', 'loss=', '0.036980623')
# ('Epoch:', '0469', 'training time (minutes)=', '0.0143', 'loss=', '0.037154257')
# ('Epoch:', '0470', 'training time (minutes)=', '0.0146', 'loss=', '0.037384981')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-470 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0471', 'training time (minutes)=', '0.0148', 'loss=', '0.036466887')
# ('Epoch:', '0472', 'training time (minutes)=', '0.0144', 'loss=', '0.037559859')
# ('Epoch:', '0473', 'training time (minutes)=', '0.0143', 'loss=', '0.036985002')
# ('Epoch:', '0474', 'training time (minutes)=', '0.0143', 'loss=', '0.038012254')
# ('Epoch:', '0475', 'training time (minutes)=', '0.0143', 'loss=', '0.038285189')
# ('Epoch:', '0476', 'training time (minutes)=', '0.0144', 'loss=', '0.037584114')
# ('Epoch:', '0477', 'training time (minutes)=', '0.0143', 'loss=', '0.037684425')
# ('Epoch:', '0478', 'training time (minutes)=', '0.0145', 'loss=', '0.037423439')
# ('Epoch:', '0479', 'training time (minutes)=', '0.0143', 'loss=', '0.039583487')
# ('Epoch:', '0480', 'training time (minutes)=', '0.0143', 'loss=', '0.040906528')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-480 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0481', 'training time (minutes)=', '0.0144', 'loss=', '0.040851639')
# ('Epoch:', '0482', 'training time (minutes)=', '0.0142', 'loss=', '0.038605564')
# ('Epoch:', '0483', 'training time (minutes)=', '0.0143', 'loss=', '0.037749854')
# ('Epoch:', '0484', 'training time (minutes)=', '0.0142', 'loss=', '0.038682165')
# ('Epoch:', '0485', 'training time (minutes)=', '0.0142', 'loss=', '0.037835741')
# ('Epoch:', '0486', 'training time (minutes)=', '0.0143', 'loss=', '0.037774027')
# ('Epoch:', '0487', 'training time (minutes)=', '0.0142', 'loss=', '0.037138142')
# ('Epoch:', '0488', 'training time (minutes)=', '0.0142', 'loss=', '0.038332837')
# ('Epoch:', '0489', 'training time (minutes)=', '0.0142', 'loss=', '0.038584284')
# ('Epoch:', '0490', 'training time (minutes)=', '0.0143', 'loss=', '0.038339701')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-490 is not in all_model_checkpoint_paths. Manually adding it.
# ('Epoch:', '0491', 'training time (minutes)=', '0.0144', 'loss=', '0.037176691')
# ('Epoch:', '0492', 'training time (minutes)=', '0.0142', 'loss=', '0.037532073')
# ('Epoch:', '0493', 'training time (minutes)=', '0.0143', 'loss=', '0.037291205')
# ('Epoch:', '0494', 'training time (minutes)=', '0.0144', 'loss=', '0.037793152')
# ('Epoch:', '0495', 'training time (minutes)=', '0.0143', 'loss=', '0.037091063')
# ('Epoch:', '0496', 'training time (minutes)=', '0.0143', 'loss=', '0.035569866')
# ('Epoch:', '0497', 'training time (minutes)=', '0.0143', 'loss=', '0.036330011')
# ('Epoch:', '0498', 'training time (minutes)=', '0.0143', 'loss=', '0.036617570')
# ('Epoch:', '0499', 'training time (minutes)=', '0.0142', 'loss=', '0.036988433')
# ('Epoch:', '0500', 'training time (minutes)=', '0.0142', 'loss=', '0.036647369')
# INFO:tensorflow:../data/single_class_ae/models.ckpt-500 is not in all_model_checkpoint_paths. Manually adding it.

# %% [markdown]
# Get some reconstuctions and latent-codes.

# %%
feed_pc, feed_model_names, _ = all_pc_data.next_batch(10)
reconstructions = ae.reconstruct(feed_pc)
latent_codes = ae.transform(feed_pc)

# %%
recon_arr, recon_loss = reconstructions
recon_arr.shape, recon_arr[0]
# Out:
# ((10, 2048, 3), array([[ 0.24808376, -0.07220863, -0.01851774],
#         [ 0.121619  , -0.22664535, -0.05162892],
#         [-0.050992  , -0.07772793, -0.02552043],
#         ...,
#         [-0.05316528,  0.02365882, -0.02594247],
#         [-0.13948913,  0.01080071, -0.03317543],
#         [-0.15718873,  0.12569316,  0.14378455]], dtype=float32))

# %%
import numpy.core.records

# %%
recon_arr_struct = numpy.core.records.fromarrays(recon_arr.transpose((2,0,1)),
                                                    names='x, y, z',
                                                    formats='f4, f4, f4')
recon_arr_struct.shape, recon_arr_struct
# Out:
# ((10, 2048), rec.array([[( 2.48083755e-01, -0.07220863, -0.01851774),
#              ( 1.21619001e-01, -0.22664535, -0.05162892),
#              (-5.09920046e-02, -0.07772793, -0.02552043), ...,
#              (-5.31652793e-02,  0.02365882, -0.02594247),
#              (-1.39489129e-01,  0.01080071, -0.03317543),
#              (-1.57188728e-01,  0.12569316,  0.14378455)],
#             [( 1.25335515e-01, -0.20750852,  0.015026  ),
#              ( 3.57898045e-03, -0.20135814, -0.16801819),
#              (-1.21016845e-01, -0.14696896, -0.14816204), ...,
#              (-6.15503825e-02,  0.03629451, -0.31195217),
#              (-1.22578651e-01,  0.05095785,  0.03149545),
#              (-1.12119175e-01,  0.12648435,  0.0948585 )],
#             [( 1.40655875e-01, -0.21427195,  0.07564928),
#              (-5.38663976e-02, -0.18669136, -0.0958605 ),
#              (-1.37459427e-01, -0.10235959, -0.14274377), ...,
#              (-8.28693062e-02,  0.00497299, -0.25441524),
#              (-1.59451723e-01,  0.0819585 , -0.00664296),
#              (-1.63400486e-01,  0.1270419 ,  0.09952231)],
#             ...,
#             [( 1.38371840e-01, -0.262285  ,  0.15999839),
#              (-3.13564204e-04, -0.22515608,  0.07294799),
#              (-1.02640964e-01, -0.32203916,  0.15110129), ...,
#              (-1.89843774e-03,  0.243822  ,  0.05285403),
#              (-8.26471150e-02,  0.02558881,  0.15617636),
#              (-7.60268420e-02,  0.0437199 ,  0.23811848)],
#             [( 3.54041964e-01, -0.06319547, -0.0448023 ),
#              ( 3.23008209e-01, -0.17466824, -0.07791113),
#              ( 1.19365267e-02, -0.06368467, -0.04220327), ...,
#              (-5.66666387e-03,  0.02143811,  0.01108494),
#              (-2.14960575e-01,  0.04376182, -0.04500283),
#              (-2.03959361e-01,  0.06129115, -0.13871019)],
#             [( 3.09418261e-01, -0.01192166, -0.1816118 ),
#              ( 2.52723217e-01, -0.04612711, -0.07867817),
#              (-9.21500921e-02, -0.06254044, -0.11642248), ...,
#              ( 1.19982194e-02,  0.14808665, -0.10963771),
#              (-2.61532933e-01, -0.06345004, -0.04489776),
#              (-3.20223689e-01,  0.11502024, -0.08359399)]],
#            dtype=[('x', '<f4'), ('y', '<f4'), ('z', '<f4')]))

# %%
import pathlib
results_dir = 'results'
pathlib.Path(results_dir).mkdir(parents=True, exist_ok=True) 

from latent_3d_points.external.python_plyfile import plyfile
el = [plyfile.PlyElement.describe(recon_arr_struct[i], 'vertex') for i in range(10)]
for i in range(10):
    plyfile.PlyData([el[i]], text=True).write(results_dir+'/test_ply%d.ply' % i)

# %%
feed_pc_struct = numpy.core.records.fromarrays(feed_pc.transpose((2,0,1)),
                                                    names='x, y, z',
                                                    formats='f4, f4, f4')
feed_pc_struct.shape, feed_pc_struct
# Out:
# ((10, 2048), rec.array([[( 0.16341881,  0.27751648, -0.30591258),
#              ( 0.1530696 ,  0.27230483, -0.3051154 ),
#              ( 0.15488185,  0.278457  , -0.3038634 ), ...,
#              (-0.02617915, -0.24882269,  0.3030783 ),
#              (-0.02030906, -0.26313043,  0.3039847 ),
#              (-0.04632105, -0.25781667,  0.30591258)],
#             [(-0.11423104,  0.04121629, -0.30969796),
#              (-0.11328048, -0.16444261, -0.30969784),
#              (-0.11247163, -0.20731589, -0.30969775), ...,
#              ( 0.02860039,  0.24116069,  0.309697  ),
#              ( 0.0389767 ,  0.27935264,  0.309697  ),
#              ( 0.03815221,  0.2881268 ,  0.309697  )],
#             [(-0.18028238,  0.3179567 , -0.28394315),
#              (-0.1268053 ,  0.32522163, -0.2838938 ),
#              ( 0.02967381,  0.34388316, -0.28359804), ...,
#              ( 0.0489579 , -0.34029528,  0.28178164),
#              ( 0.04090161, -0.34169525,  0.2820895 ),
#              (-0.02727016,  0.34227726,  0.28394315)],
#             ...,
#             [(-0.0429877 , -0.3855309 , -0.242724  ),
#              ( 0.08844629, -0.38448614, -0.242724  ),
#              ( 0.07057104, -0.3819807 , -0.242724  ), ...,
#              (-0.0974418 ,  0.0351461 ,  0.24209967),
#              (-0.10031683,  0.355027  ,  0.2421872 ),
#              (-0.09856595,  0.14347528,  0.24223702)],
#             [(-0.20378248,  0.07088041, -0.27356517),
#              ( 0.3182585 ,  0.16938093, -0.27307394),
#              ( 0.13571748, -0.16875817, -0.27239028), ...,
#              ( 0.34447718, -0.12151294,  0.26987255),
#              ( 0.35976806, -0.12204455,  0.27018598),
#              ( 0.26930466, -0.12399708,  0.27032477)],
#             [( 0.2476482 , -0.14427647, -0.28468373),
#              ( 0.2500596 ,  0.17243285, -0.2840847 ),
#              ( 0.25100476,  0.17922162, -0.28305337), ...,
#              ( 0.21441665, -0.13135692,  0.2820849 ),
#              ( 0.2387686 , -0.13159302,  0.28372955),
#              ( 0.21577813, -0.12946601,  0.2839667 )]],
#            dtype=[('x', '<f4'), ('y', '<f4'), ('z', '<f4')]))

# %%
feed_el = [plyfile.PlyElement.describe(feed_pc_struct[i], 'vertex') for i in range(10)]
for i in range(10):
    plyfile.PlyData([feed_el[i]], text=True).write(results_dir+'/train_ply%d.ply' % i)
